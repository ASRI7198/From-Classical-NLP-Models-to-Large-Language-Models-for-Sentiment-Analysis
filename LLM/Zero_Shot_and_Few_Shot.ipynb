# %%
import sys
sys.path.append('C:/Users/DELL/Desktop/NLP')
import os
import config as args
from transformers import pipeline
from huggingface_hub import login

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = args.TOKEN_HUGGINGFACE

# %%
login(token=args.TOKEN_HUGGINGFACE)

# %%
generator = pipeline(
    "text-generation",
    model="mistralai/Mistral-7B-Instruct-v0.2",
    device=-1
)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00, 55.12it/s]
# Device set to use cpu

# %% [markdown]
# ✅ ZERO-SHOT

# %%
prompt = """
Instruction: Classifie la phrase suivante selon l'émotion qu'elle exprime parmi [sadness, joy, anger, fear, love, surprise].

Phrase: i feel so happy today
Réponse:
"""

# %%
result = generator(prompt, max_length=100)
print(result[0]['generated_text'])
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Instruction: Classifie la phrase suivante selon l'émotion qu'elle exprime parmi [sadness, joy, anger, fear, love, surprise].
#
# Phrase: i feel so happy today
# Réponse:
# The phrase "I feel so happy today" expresses the emotion of joy.

# %% [markdown]
# ✅ FEW-SHOT

# %%
phrase = "i jest i feel grumpy tired and pre menstrual which i probably am but then again its only been a week and im about as fit as a walrus on vacation for the summer"

prompt = """
Instruction: Classifie la phrase suivante selon l'émotion qu'elle exprime parmi [sadness, joy, anger, fear, love, surprise].

Exemples:
Phrase: i didnt feel humiliated
Réponse: sadness

Phrase: i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake
Réponse: sadness

Phrase: im grabbing a minute to post i feel greedy wrong
Réponse: anger

Phrase: i am ever feeling nostalgic about the fireplace i will know that it is still on the property
Réponse: love

Phrase: i am feeling grouchy
Réponse: anger

Phrase: ive been feeling a little burdened lately wasnt sure why that was
Réponse: sadness

Phrase: ive been taking or milligrams or times recommended amount and ive fallen asleep a lot faster but i also feel like so funny
Réponse: surprise

Phrase: i feel as confused about life as a teenager or as jaded as a year old man
Réponse: fear

Phrase: i have been with petronas for years i feel that petronas has performed well and made a huge profit
Réponse: joy

Nouvelle phrase: {phrase}
Réponse:
"""

# %%
result = generator(prompt, max_length=100)
print(result[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Instruction: Classifie la phrase suivante selon l'émotion qu'elle exprime parmi [sadness, joy, anger, fear, love, surprise].
#
# Exemples:
# Phrase: i didnt feel humiliated
# Réponse: sadness
#
# Phrase: i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake
# Réponse: sadness
#
# Phrase: im grabbing a minute to post i feel greedy wrong
# Réponse: anger
#
# Phrase: i am ever feeling nostalgic about the fireplace i will know that it is still on the property
# Réponse: love
#
# Phrase: i am feeling grouchy
# Réponse: anger
#
# Phrase: ive been feeling a little burdened lately wasnt sure why that was
# ...
